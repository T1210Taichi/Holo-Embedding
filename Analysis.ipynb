# %% [markdown]
# # 目的
# 動画情報を得られたので、興味本位でグラフとかにしてみたい。

# %% [markdown]
# # import

# %%
import csv
import pandas as pd
from matplotlib import pyplot

# %%
df = pd.read_csv("20230122_042615_大空スバル_UCvzGlP9oQwU--Y0r9id_jnA_channel-video-info.csv")

# %%
publishedAt = df["publishedAt"]
viewCount = df["viewCount"]

# %%
publishedAt_dt = pd.to_datetime(publishedAt)

# %%
pyplot.plot(publishedAt_dt, viewCount)
pyplot.show()

# %%
publishedAt
# Out:
# 0      2023-01-21T16:36:57Z
# 1      2023-01-21T12:34:12Z
# 2      2023-01-21T11:28:14Z
# 3      2023-01-21T10:58:09Z
# 4      2023-01-20T14:52:15Z
#                ...
# 746    2021-11-30T14:00:11Z
# 747    2021-11-29T11:00:27Z
# 748    2021-11-28T16:03:22Z
# 749    2021-11-28T13:07:18Z
# 750    2021-11-28T13:00:11Z
# Name: publishedAt, Length: 751, dtype: object
