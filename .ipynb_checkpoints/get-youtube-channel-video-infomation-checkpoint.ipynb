# %% [markdown]
# # 目的
# https://diy-programming.site/youtube/channel-video-info-get/#toc12
#
# youtubeの特定のチャンネルの動画情報を取得することを目的とする。
# 上記サイトを参考に進める。
#
# また、チャンネルIDは既知とする。

# %%
import os
import urllib
import urllib.request
import urllib.parse
import json
import csv
import isodate
import datetime

import requests

APIKEY = os.environ["HoloEmbeddingYoutubeAPI"]
channel_id = 'UCsFn_ueskBkMCEyzCEqAOvg'

# %%
outputs = []
outputs.append(["publishedAt","title","description","url","thumbnail_url","categoryId",
                "liveBroadcastContent","duration","viewCount","likeCount","favoriteCount",
                "commentCount","embedHtml","actualStartTime","actualEndTime","scheduledStartTime"])
dt_now = datetime.datetime.now().strftime('%Y%m%d_%H%M%S')
#CSV書き込み
with open(dt_now + '_' + channel_id + '_channel-video-info.csv', 'w', newline='', encoding='UTF-8') as f:
    writer = csv.writer(f)
    writer.writerows(outputs)

# %%
#################################################
#チャンネルのアップロード済み動画のPlaylistIdを取得
#################################################

channel_param = {
    'part':'contentDetails',
    'id':channel_id,
    'maxResults':50,
    'order':'date',
    'type':'video',
    'key':APIKEY
}

channel_target_url = 'https://www.googleapis.com/youtube/v3/channels?'+urllib.parse.urlencode(channel_param)
print('upload playlist id取得')
print(channel_target_url)

channel_req = requests.get(channel_target_url).json()
playlistId = channel_req["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]

#################################################
#playlistの全ての動画を取得
#################################################
nextPageToken = ''

while True:
    playlist_param = {
        'part':'snippet',
        'playlistId':playlistId,
        'maxResults':40,
        'order':'date',
        'type':'video',
        'pageToken':nextPageToken,
        'key':APIKEY
    }

    playlist_target_url = 'https://www.googleapis.com/youtube/v3/playlistItems?'+urllib.parse.urlencode(playlist_param)
    #print('動画リスト取得')
    #print(playlist_target_url)
    playlist_req = urllib.request.Request(playlist_target_url)
    try:
        with urllib.request.urlopen(playlist_req) as playlist_res:                
            #################################################
            #現ページの全ての動画を取得
            #################################################    
            videoId = ""
            playlist_body = json.load(playlist_res)
            for item in playlist_body["items"]:
                videoId = videoId + item["snippet"]["resourceId"]["videoId"] + ","

            video_param = {
                'part':'id,snippet,contentDetails,liveStreamingDetails,player,recordingDetails,statistics,status,topicDetails',
                'id':videoId,
                'key':APIKEY
            }

            video_target_url = 'https://www.googleapis.com/youtube/v3/videos?'+urllib.parse.urlencode(video_param)
            print('動画情報取得')
            print(video_target_url)

            video_req = urllib.request.Request(video_target_url)
            try:
                with urllib.request.urlopen(video_req) as video_res:
                    #################################################
                    #情報を取得
                    #################################################       
                    video_body = json.load(video_res)
                    
                    outputs = []

                    for item in video_body["items"]:
                        #値が存在しない場合ブランク
                        publishedAt = item['snippet']['publishedAt'] if 'publishedAt' in item['snippet'] else ''
                        title = item['snippet']['title'] if 'title' in item['snippet'] else ''
                        description = item['snippet']['description'] if 'description' in item['snippet'] else ''
                        url = 'https://www.youtube.com/watch?v=' + item['id'] if 'id' in item else ''
                        thumbnail_url = item['snippet']['thumbnails']['high']['url'] if 'thumbnails' in item['snippet'] else ''
                        categoryId = item['snippet']['categoryId'] if 'categoryId' in item['snippet'] else ''
                        liveBroadcastContent = item['snippet']['liveBroadcastContent'] if 'liveBroadcastContent' in item['snippet'] else ''
                        if 'duration' in item['contentDetails']:
                            #durationを時分秒へ変換
                            duration = isodate.parse_duration(item['contentDetails']['duration'])
                        else:
                            duration = ''
                        viewCount = item['statistics']['viewCount'] if 'viewCount' in item['statistics'] else 0
                        likeCount = item['statistics']['likeCount'] if 'likeCount' in item['statistics'] else 0
                        favoriteCount = item['statistics']['favoriteCount'] if 'favoriteCount' in item['statistics'] else 0
                        commentCount = item['statistics']['commentCount'] if 'commentCount' in item['statistics'] else 0
                        embedHtml = item['player']['embedHtml'] if 'embedHtml' in item['player'] else ''                        
                        
                        if "liveStreamingDetails" in item:
                            actualStartTime = item["liveStreamingDetails"]["actualStartTime"] if "actualStartTime" in item["liveStreamingDetails"] else ''
                            actualEndTime = item["liveStreamingDetails"]["actualEndTime"] if "actualEndTime" in item["liveStreamingDetails"] else ''
                            scheduledStartTime = item["liveStreamingDetails"]["scheduledStartTime"] if "scheduledStartTime" in item["liveStreamingDetails"] else ''
                        outputs.append([publishedAt, title, description, url, thumbnail_url, categoryId,
                                        liveBroadcastContent, duration, viewCount, likeCount, favoriteCount,
                                        commentCount, embedHtml, actualStartTime, actualEndTime, scheduledStartTime])

                    #################################################
                    #CSVに追記
                    #################################################    
                    with open(dt_now + '_' + channel_id + '_channel-video-info.csv', 'a', newline='', encoding='UTF-8') as f:
                        writer = csv.writer(f)
                        writer.writerows(outputs)        

            except urllib.error.HTTPError as err:
                print(err)
                break
            except urllib.error.URLError as err:
                print(err)
                break

            if 'nextPageToken' in playlist_body:
                nextPageToken = playlist_body['nextPageToken']
            else:
                break
        
    except urllib.error.HTTPError as err:
        print(err)
        break
    except urllib.error.URLError as err:
        print(err)
        break
# Out:
# upload playlist id取得
# https://www.googleapis.com/youtube/v3/channels?part=contentDetails&id=UCsFn_ueskBkMCEyzCEqAOvg&maxResults=50&order=date&type=video&key=AIzaSyB-V6KwoU3brZpcmfMPmDN_7-r5EyotRSg
# 動画情報取得
# https://www.googleapis.com/youtube/v3/videos?part=id%2Csnippet%2CcontentDetails%2CliveStreamingDetails%2Cplayer%2CrecordingDetails%2Cstatistics%2Cstatus%2CtopicDetails&id=kLbrN3sXGDU%2CKDB-H_XRLfw%2CWxKI2WNYBtI%2C19r2mGKCI4E%2CkCbC3P-8RPU%2CL2kycq143yQ%2C-DFVS73xt2s%2CX_TWnHJfVRc%2ChQbq4r1BSj4%2CJ1lpoK_XIv4%2CahCGMVdJCy4%2CZhhZmmTN9NM%2C6UDhX6xVJf8%2C9nsfBdbv0b4%2C80EwP9FJvdU%2Cv5jQeK-KHQo%2C66zGOt0LJ5Q%2CBdWks9g_47c%2CqumBTvXMOFA%2CdsBaBn7XrGM%2CzB5hvQdE06U%2COkV49kvjnSQ%2CW0H_EsPRQzs%2CU2A80VKqtcw%2CEICoJjLz_nQ%2CRlTlchXmLxc%2CCPtFZaqyV9I%2Cxas2H5mbwq8%2Cj_npmWsXkdM%2CiCoUqqkbePI%2C79xbnihqSXg%2COFjJHoJB23Y%2CR8lprHrDAGU%2CWhvjtKKTWzw%2CDQhHSPeFd9U%2CDBVUmhKQogM%2CcDZ5OIxGwm4%2CTh4Ij4TBrVU%2CAnM2t_yDYKY%2Cx0GpsRzwJXA%2C&key=AIzaSyB-V6KwoU3brZpcmfMPmDN_7-r5EyotRSg
# 動画情報取得
# https://www.googleapis.com/youtube/v3/videos?part=id%2Csnippet%2CcontentDetails%2CliveStreamingDetails%2Cplayer%2CrecordingDetails%2Cstatistics%2Cstatus%2CtopicDetails&id=eHwmqRNpho4%2Cg6kv0YsILh0%2CkH0rUyTjK2s%2CIEiNvBKcsAI%2C8-ozQ4F1N04%2CZUOQhivtXA0%2CgLtrKWUCKLE%2C5MvwDo3RwvQ%2C10I_OgYkvSU%2CUHsVs1-UjVQ%2CYBIkWoGDI4s%2Crb2WzXlgOfw%2C2CXlcRDhURU%2Cp-x481qzHSs%2C-pHEuR5mrrg%2CGHPyRujVO9c%2CKoICl-Yvvv0%2Cjt1VDgus7ZM%2CSWr9RUwUw44%2CaiYtAzG_u3M%2CTAFA4pavi2E%2CquZNgSX2Pxg%2C7C0rZQy_qqk%2CVALUDKncZuQ%2Co6hEk2r7OXs%2CUgzTotJSZl4%2C4ixyoyJEgcY%2C4ZEXPSVwyCo%2C-F5h3lsuhWI%2CxE2Nhj5eUHY%2Cq4pIjbQcx74%2CQ5C5wvmJsxs%2Cb2B-bzegEAc%2Cejs6yj-rm8Q%2CX2bCGUZnPBY%2Cn_RZvP21crA%2CJvscHdBTOBk%2C3flrpEzYSVE%2C2Rrhi9uACxQ%2CHaW00vMjmPA%2C&key=AIzaSyB-V6KwoU3brZpcmfMPmDN_7-r5EyotRSg
# 動画情報取得
# https://www.googleapis.com/youtube/v3/videos?part=id%2Csnippet%2CcontentDetails%2CliveStreamingDetails%2Cplayer%2CrecordingDetails%2Cstatistics%2Cstatus%2CtopicDetails&id=qP6gjRmHj3Q%2Cq1BL1PAh5w8%2C9OZr6BhJVXc%2CbaMqZm0JKSQ%2CeGu0lpGe6_I%2Cw0gjVNRUpZQ%2CRGmaNnFo8rU%2CC36AhVgQ8SY%2CBeb--p-FBvQ%2C2HiL66khK3A%2C9HonubmvgIg%2C9havek5G4Mk%2C8Yxeitv4Zlw%2CnqWyWVk0es8%2CpA9naDVX0_o%2CAX3QQrLKcVo%2CKT66QBYgKrE%2CDMQCRWpCpWA%2C0E1lV-i0CJo%2C1-G0CyZ2lQc%2CpGO4sQEIjfI%2CEwt1K5qh6sM%2CBiUSg5LrPno%2C9om1qgRMfU0%2CS00cIpN1RQQ%2COouhC4uKdR0%2C7Fk1Nxf49ig%2CegBc6-Evr7g%2CQ66i91TVmAw%2C-WILotYz19s%2C0jGHbLlbkNY%2CBWPRPjUibCI%2CWJ5jjTei2Wo%2C25H7P9UwurA%2C9ji8qnWe73I%2CauqiSpRXewI%2C-yqXE1fx4ok%2CtOdYF7BDcic%2CQu9hTmWX7l4%2CjmExmiXlqcU%2C&key=AIzaSyB-V6KwoU3brZpcmfMPmDN_7-r5EyotRSg
# 動画情報取得
# https://www.googleapis.com/youtube/v3/videos?part=id%2Csnippet%2CcontentDetails%2CliveStreamingDetails%2Cplayer%2CrecordingDetails%2Cstatistics%2Cstatus%2CtopicDetails&id=n-AR1mo-nqk%2CEB1N1CUHsas%2CZnROfzClQuY%2CUmfiDfywaO4%2C2dJk9ldCEbg%2CRDYeelT3R8c%2CarnG3fESAC4%2CD13zxt4C51E%2CsSu-3pmdIxc%2CBPaME6TX5m8%2C3tTHjIPNYLI%2CdKCFjA8A3bo%2CvoPhradTrLw%2CMEIy11wZZN4%2CxsiCJCLluo8%2CLQqfpzib7iE%2C52mX5XTWcA0%2C0myHYfKuW5o%2CJVRjawuwya4%2CbG6tXXbBVx4%2CHeSqGV7wzQU%2Crhtlcsa0GZQ%2CythDAe0Xt0U%2C_CUNIjZLt7M%2CZPOqWi2yFCY%2CfjmnXqiA0bA%2C4SImVsbh3uU%2Ckk2Q8aiQvm8%2C1a8T6RZJDD8%2C7TyZm9pznz0%2CCt3xcJ9t_pw%2COQsmXAka6FU%2CaiOnroeb95E%2CtnJayBKSDNU%2CwcsNhUOxpyI%2ChjU9_-51ILo%2CVYVwMb-1Kw0%2C6zkaWEyl3j8%2CT3aqlfKHYfQ%2C8a_FzUu6MKA%2C&key=AIzaSyB-V6KwoU3brZpcmfMPmDN_7-r5EyotRSg
# 動画情報取得
# https://www.googleapis.com/youtube/v3/videos?part=id%2Csnippet%2CcontentDetails%2CliveStreamingDetails%2Cplayer%2CrecordingDetails%2Cstatistics%2Cstatus%2CtopicDetails&id=7Tp6_nrbIn8%2C1Cgxy-SDDmE%2CfVdqjMUhTwA%2Cp7kXCid4vLc%2C6EOrohIbyj8%2Cbk8bxa0kId0%2C6e6opNIiGFQ%2CbJkgFDP0VJs%2CCisZDO2OwSs%2CIRz6uK2Xj_c%2C9UwK-6Gy-Ok%2CoHeGKzO1_zw%2CNqRxsTPhFJM%2C0QTU9G8rEdM%2CW6Lr6GgKdxA%2CsWoDH8prOic%2C63tBTokrdaQ%2CoZ-x-Hvj0Nc%2CSvPUz0X5ZOg%2C1mlPV-_93V8%2CaGusSU22ssA%2C6pznKw2apb0%2CpgyjQ0FBU4s%2CsKRZcPbc9Ro%2CrYXeE8lTYQE%2Cc4PEc_yeD3A%2CSoLsZb96dto%2CUp9Kr2LpOwY%2CI_XkG-O-D_8%2CzdLwYUKVItY%2CVtxpI5A5Zsc%2CC3kmpiSgFQU%2C2WfPDe-QFNM%2CEWr2z6IkNfs%2ChEx5HxqT4V0%2Crmgxi6xrQd4%2CpT7pU9Vq0gA%2C2eQhJHooHSs%2C7zKgl22b3pI%2CD6Aic1awRPE%2C&key=AIzaSyB-V6KwoU3brZpcmfMPmDN_7-r5EyotRSg
# 動画情報取得
# https://www.googleapis.com/youtube/v3/videos?part=id%2Csnippet%2CcontentDetails%2CliveStreamingDetails%2Cplayer%2CrecordingDetails%2Cstatistics%2Cstatus%2CtopicDetails&id=YnMVaiF2EPk%2Cu8kXXCM0IDw%2CDUhcVfaKVMU%2CAqXfNO5lzSs%2C5szqVTo3JME%2CQ6NRYSQiPQk%2Chw5ZpHepJSk%2CAk1dx80YzF4%2C66ComYXzxeE%2CnmSifIz5ugA%2Cv4jyb2Gji_4%2C7qNexuP6qhA%2CEXBs0R2TSZ4%2CQ_Fc86Zt_4s%2CspgKluAU2Pw%2CHBMdp6gTvTk%2CNokeOPzc4ig%2CB1cAK-dmXRM%2CAJHAJAVhNrk%2CisfV-ByFakw%2CDykJK1CfSyo%2CO-4cbRTvXC4%2CsA4v47CiRc8%2Ck_pBNwrfdoE%2CR6upwrgMLEA%2CqyxilwRZCec%2CveRGiAfPWxs%2CI1rEEi9pPxo%2C_g0X8xNHso4%2CJGP2s_XnhqQ%2CACHG4qibXRk%2CR87z7aMWX6E%2C0Z31Nhz1ORQ%2CRdaOF_x_zs8%2CcCRAwQyOgnw%2C6qGR8f3egNw%2CEy_PCwKShOE%2C5TmRcOlj6C8%2CD9yl8DHRSso%2C1CXAjnHlTIY%2C&key=AIzaSyB-V6KwoU3brZpcmfMPmDN_7-r5EyotRSg
# 動画情報取得
# https://www.googleapis.com/youtube/v3/videos?part=id%2Csnippet%2CcontentDetails%2CliveStreamingDetails%2Cplayer%2CrecordingDetails%2Cstatistics%2Cstatus%2CtopicDetails&id=-sU0yy5UPFM%2Cu7zdapXUi9I%2CeyXp67F75TA%2CAJdPXJr8UnE%2CUJ_J_Gl8Lt8%2CV3-u8s7qyxM%2C6J0IKBcuUmU%2CeZCtUJdjTmM%2CYlIu_dwr_44%2Cp1OFCwdtKxU%2CyUMTgmDyViY%2CcyTXoQgelS4%2CDJ_NhyV6dlc%2CnbE_pVUah6o%2CN3ZMgq3dpkM%2CwXnrsTGbVmA%2CetGt1afBGLg%2CpAWEYCV7mdI%2CE7ccYKR5FN0%2CaCR8wjyWJIw%2CBne6R92WzF8%2CDj02EPXb3ZU%2CefI9KAZSmq0%2CUxriA-njt3c%2CS8NZIj2snJA%2Cw140GDq-rLA%2CrRovLpWhaoI%2CQBQZViHXfRo%2CMEh9-ykjG7A%2CaRfsE6y8TZ0%2CVfcW010A234%2CfFRDtd7ooRQ%2C3A6GPqLxeNA%2CZT9fxAYKDG0%2CNOMZthH0Wac%2CjaOUSZR40K8%2CfRRTDGwlISg%2CRE6JWsvOFG0%2CTzM6cLeoi_c%2CPVmdU6yRh6Y%2C&key=AIzaSyB-V6KwoU3brZpcmfMPmDN_7-r5EyotRSg
# 動画情報取得
# https://www.googleapis.com/youtube/v3/videos?part=id%2Csnippet%2CcontentDetails%2CliveStreamingDetails%2Cplayer%2CrecordingDetails%2Cstatistics%2Cstatus%2CtopicDetails&id=LFLIdR42Pxk%2CvMo90FTvM80%2Ci65xQuNbdcw%2C8z3d-Z96iMA%2CTAo3XkqaqU4%2ClI9fbMQ0xn0%2Cdwb0qMDADtw%2COU-gmyuE3yg%2CX013Vo-0XNM%2CLoe6Y8TRG3c%2CHT1_GSP9kJU%2CQ4qNY8mIdQY%2CRw5USaCCav4%2CiAqmDa-6yPs%2CBjRBrtFuBBM%2CKkudFmbE9EE%2C88CwFFPgaGw%2CFb2qbpk27yU%2C54pPgsgRLHM%2Cbu45VYBPyGo%2CCHAu3BElYmM%2CXzG9Az8V3nU%2CeBgZ-nMXaUI%2CoPXxjrtLO1k%2C6meNtzzGZq0%2CKLbUmVjwIjo%2C0LDVFTfKrlw%2CFUPAs_GW-5w%2COp0cd6u1OIg%2C95uGBuvF_hE%2COkSJ4D6LyPU%2CvK0kYW6x3x8%2COyQ0laWAAkI%2Cvxmrzbkswmc%2CKi1cY8BjJkw%2CnSLnqqnkGLA%2Cceih4rnkCTk%2CY0Q0vDfmjTY%2CHVhVypX1Nvw%2Crsj6_T3Xjz0%2C&key=AIzaSyB-V6KwoU3brZpcmfMPmDN_7-r5EyotRSg
# 動画情報取得
# https://www.googleapis.com/youtube/v3/videos?part=id%2Csnippet%2CcontentDetails%2CliveStreamingDetails%2Cplayer%2CrecordingDetails%2Cstatistics%2Cstatus%2CtopicDetails&id=Q9mCwm0YmW8%2C_GoEuGKnOYw%2CfVFK7nLtv_w%2CqBTXgu03no0%2CEu4Tl-u-B4U%2CyKwcOyqtJSs%2CuCa_ZcPzwF0%2C_NOnpbPz-Fo%2C5zsblKdoEE0%2CcxHfXYqEJP4%2CDiHGLGQQGy8%2CGZCyh4Zo5cM%2C8sJB5UuwwZE%2CgSKvKuhhScU%2CoXBmIT5r4N8%2ChPc6HYymFw0%2CgKIB3JX1oBs%2C4xMiIn0ETGg%2CcHmbF9-oYGA%2CzlpKlm_9T3w%2CC_3eWSwrucg%2CP-X8tb09jx0%2C8_ON17SEqIM%2CNyZ1khMr0Yc%2CbqXcy1lTbtI%2CJODS3z-8C28%2CK8aDhDw9Qwk%2Ck4o6jF10oBQ%2CHWK7PE5OgaU%2CGiSDWC4vwU4%2CT6pQB8EdkB4%2CL-u4rBtw-QA%2CWVafA2LPmwY%2C7k25QikWxG0%2CJB4PPsSUo4A%2CCyLKSq4Yj-k%2CqSyFZ8RdyT4%2C-lQSbEy7YBw%2Cba81TlzOh2A%2C3rDNfZwft14%2C&key=AIzaSyB-V6KwoU3brZpcmfMPmDN_7-r5EyotRSg
# 動画情報取得
# https://www.googleapis.com/youtube/v3/videos?part=id%2Csnippet%2CcontentDetails%2CliveStreamingDetails%2Cplayer%2CrecordingDetails%2Cstatistics%2Cstatus%2CtopicDetails&id=cQetNOGzvU8%2CeFhVfoOgKCo%2CUV8I0Sm1DEg%2CD7BX7MCBVm0%2CE1zohxRfC38%2CxH-9cmkGdJ8%2CG7a8cGeVHSE%2C_0a7t2hGDw0%2C7WkbFK3Ozhk%2CMRPnFeWN0sY%2CWxGHZJe7mUQ%2CXDXNOBvjC00%2CVZHJnUjlxFo%2CD108O-JcqKM%2CRyfv09mvfXM%2CCQMgcX--ouA%2C58kJgf_pZ2o%2Cg1k4tZf6Gvg%2CpxH1jEj8GZs%2C0jgu00lxrEo%2CNTVjQ-LmfFA%2Ci9rQZNVz7hg%2Cx_UWaBLk-9s%2CPSZLEJVZGOk%2CxTPiK27730g%2C0ASDp3FQn38%2CEnHZUaWBxYk%2C2Hb6hZOxJ1s%2CmkxrLyHEdM0%2CmqnWcnxu-oU%2CMMe1p-wZ9xA%2C6T4SIj5Y0jQ%2C9omPYSESf8Y%2Ce4pyxE5-IIo%2C-wWQYKTIuBI%2C7SCsEXorTMM%2COPe_LZ58lkI%2C2_Fn-PPlInc%2CKNBcwXOGP24%2COPP-VbYm0FY%2C&key=AIzaSyB-V6KwoU3brZpcmfMPmDN_7-r5EyotRSg
# 動画情報取得
# https://www.googleapis.com/youtube/v3/videos?part=id%2Csnippet%2CcontentDetails%2CliveStreamingDetails%2Cplayer%2CrecordingDetails%2Cstatistics%2Cstatus%2CtopicDetails&id=zU-_Xnpa_gs%2CFA5-KIXuj6U%2C432nOZp_P-E%2CCYU_koHT0xw%2CBM2Yr52wvrU%2CPQF1rskIg3Q%2CVWulVXuK9aI%2C_c04E70cieY%2CrSPMiEzE9-U%2CEUepIDJCJto%2CgnWNHWyA_8w%2CAecUuZByBbI%2CBIQKCrc03l4%2Cr6FQwNfDZ-I%2C1oLcUmDNNI8%2CXLeBOiFMGtM%2CW3oOzoqpxPc%2C5B40JxQH94Y%2CNJrSA5_MhP0%2C_tnkcOJdQX0%2CvSLK1KVZjrY%2Cqbj6HfTz8tc%2CWxi_PX_FeRU%2C93yPJ27qal4%2CLBg9CAjZvYU%2CYNDBprBHO_s%2CKgtRTY--GMU%2C2uyVOh3NxzA%2CkCgdwXAnxIE%2CksS732XgQeM%2CgkD93pzS-Gw%2CZwtUWNZkvHY%2CjqyI5nkNBEA%2CjRae3aaAHUc%2COKbhuOKSw_k%2CigxX4XkPEvQ%2CD_L4cp-dhmU%2Cp1rsZE8ge-k%2CW1CuO1sDEmg%2CF8dpZ3x0rdo%2C&key=AIzaSyB-V6KwoU3brZpcmfMPmDN_7-r5EyotRSg
# 動画情報取得
# https://www.googleapis.com/youtube/v3/videos?part=id%2Csnippet%2CcontentDetails%2CliveStreamingDetails%2Cplayer%2CrecordingDetails%2Cstatistics%2Cstatus%2CtopicDetails&id=eZtgKA0C-hY%2Csq2xr294QEk%2ChfZ-G7J1gP4%2CleN8a8mG3qw%2C3VLwfvajtb0%2CE3uzlZjikAs%2C5xBZjogSVPI%2Cl2_3EYkDmyc%2CpOHOgCS7lao%2C_v7n4IM51pA%2COnDU5KJOdys%2CiA4TEHfoWYc%2CeNir5sTq0C8%2C8xzfY3Ik-Do%2CqwLZ46ILVFU%2CutqgP319UPI%2C5t40OEX2-VM%2CC3oUQ91WhFA%2CS24Y1Ps3N8s%2CIBDqZe-FjHY%2C5FdAzd5J6Ao%2CkuD57DZwN_Q%2CXJN3aFRo-Yk%2CQPGBbAEIn4M%2CDM0voe1YQ0k%2C3pRXWZmSt8k%2C59H5SHqU8hE%2Czit8FYP3unM%2C_gOpgTQf7pk%2CLyYQv_rtjqo%2CwSCM1ySqBJc%2CBx1KNWoChEw%2C9ddVh0zIAnk%2CttTZGa3hJkA%2C1sON-TmboYY%2CWlAluuwlguw%2CCIOjlp07XSs%2Cn6qaSHygnJY%2C8UNRT75gTuc%2C1P4MA8Xspbw%2C&key=AIzaSyB-V6KwoU3brZpcmfMPmDN_7-r5EyotRSg
# 動画情報取得
# https://www.googleapis.com/youtube/v3/videos?part=id%2Csnippet%2CcontentDetails%2CliveStreamingDetails%2Cplayer%2CrecordingDetails%2Cstatistics%2Cstatus%2CtopicDetails&id=n58Sirr4vkc%2C-d4p8Z9hI2o%2C6r5Cm1hDh3s%2CtLLjXFjlgeQ%2CfUS-NQ0Xr8Y%2CgVnRLY8V8EM%2C_rIrNy7_e0c%2CD0qVhqmc0K4%2CN1wQ2RxvJ9g%2CHbBcSbX8UWA%2CLBiDfvFDNmY%2CeA1G3v2jYJU%2CH0yXh6DB6Sg%2CarXfWGgpmQo%2CDbjKLC0PYOE%2C8jeTWLvknEc%2CKJaDWR3MDu8%2C709-AW0LQ8U%2C-INNpRA0pWY%2CYrVMFh-qadE%2CpswVRMOZOZY%2CpOSc92OLFNM%2CdaOXAfK-rs8%2CkVMTPT6p6sY%2Ct7Po-jr9cYA%2C1-IeB7_4r-U%2COOjECYiBOVk%2CugFfOeAT-rk%2C1Hzrjk1BZ1U%2C20IpI7izWX4%2CJKmtVYaABwo%2CHu75bfzVtvg%2CTaPkOSP0Y74%2Cox1FkWTBUG8%2C7J56jypdnGQ%2Cd5BTy8eWD_U%2CeiIeBlaeoXw%2CWLUbziYGSkA%2CitStOOXN0jY%2CsoVfWo15q9k%2C&key=AIzaSyB-V6KwoU3brZpcmfMPmDN_7-r5EyotRSg
# 動画情報取得
# https://www.googleapis.com/youtube/v3/videos?part=id%2Csnippet%2CcontentDetails%2CliveStreamingDetails%2Cplayer%2CrecordingDetails%2Cstatistics%2Cstatus%2CtopicDetails&id=o2nN4wcGTbU%2CC9wsHwsOc5M%2ChlfdDRIf8TE%2CuOwRhr5gkEE%2C00ICcoxnbPM%2CjdC754ZEA_U%2C1yCqOMotmHc%2CJyAcvKKeQLI%2CMntZtLEizPI%2CK81ZC0PDQfU%2CTGE-AzaB7zQ%2CdohItQ1sNvs%2CYWaZPMt9ZJw%2C5iaQ90gcak8%2CssIFoKHjLrs%2CADR1w7QUYPU%2CDE6bc_EGoBQ%2C4ijEe4MARow%2CaIGxc_V8o1s%2C8o947tLiFhA%2CY9VApJUbV3g%2CYj5-CH0hDXc%2CzfNd9sFCmqI%2CyL82tTLVNHU%2Cer5bHlOjYo4%2CFqU9gBpAg9o%2CDgAql7UCF9U%2CmfTnfeUYkuo%2CVQZmzyvBCnc%2CQUEqDIpuoc8%2CvntAfzmq1Hs%2C4NujgnV-xoI%2CPvgz6bUU8Pc%2CM_6bOhjoy8I%2C9t3TF3GgK04%2C6miQZNbQCdk%2COKzpHbkOz3E%2CoSJYnNeEo2w%2CWs0GNliV6lw%2CR0Lal9j4z1w%2C&key=AIzaSyB-V6KwoU3brZpcmfMPmDN_7-r5EyotRSg
# 動画情報取得
# https://www.googleapis.com/youtube/v3/videos?part=id%2Csnippet%2CcontentDetails%2CliveStreamingDetails%2Cplayer%2CrecordingDetails%2Cstatistics%2Cstatus%2CtopicDetails&id=3rKyC3zQoCI%2CAiB8PlkJ77U%2CHLJfDPDt8e0%2C74myz1iKeC0%2C5h6RPd4X2Xw%2CylBx4DNrs_A%2CHXw4G8hPZPY%2CQmyPg0v3hiA%2CE8Py6qi3rIo%2CbZcs5xhFkWE%2CIDm7UAcMhBQ%2CGHBAkHEAdH4%2CP_rxaETY0hQ%2CpFLpR1NZXlg%2CpdJf6SeLr8w%2CbeWC-B7pjvQ%2CZhtVVklshx8%2CcDQzSVFZnGU%2CYTOwarKbTZo%2C_AZMA2ch7AU%2CpGnfLT-DveA%2CyBu0zhnbfFA%2CrsDjfCr1234%2C8cgM-Up8Nqg%2Cz1L7ZUch1cQ%2CRn4EsV-Ng8w%2CaY5jNNcxg6g%2C16odYw0aHZo%2CeTbfmZJPVq0%2C5o8rhDNcReo%2ClixtISaRmBU%2CPveERjmy6bk%2Cr2dzoLa0SR4%2CVHYIaBvKF8w%2CYujgokoueKA%2CxP8qks8CLmg%2CgReqs2Onsk8%2CoRKw5QX9_uc%2CUkF1uWcElcI%2CWMcQ7egsucM%2C&key=AIzaSyB-V6KwoU3brZpcmfMPmDN_7-r5EyotRSg
